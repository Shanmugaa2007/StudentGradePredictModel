# %% [markdown]
# <a href="https://colab.research.google.com/github/Shanmugaa2007/StudentGradePredictModel/blob/main/StudentGradePredictModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('student_performance_dataset.csv')

# %%
df
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
#     parental_education internet_access extracurricular_activities  \
# ...

# %%
df.count()
# Out:
# student_id                    1000
# gender                        1000
# study_time_hours              1000
# attendance_percent            1000
# sleep_hours                   1000
# parental_education             898
# internet_access               1000
# extracurricular_activities    1000
# part_time_job                 1000
# previous_grade                1000
# final_exam_score              1000
# final_grade                   1000
# dtype: int64

# %%
df.isna().sum()
# Out:
# student_id                      0
# gender                          0
# study_time_hours                0
# attendance_percent              0
# sleep_hours                     0
# parental_education            102
# internet_access                 0
# extracurricular_activities      0
# part_time_job                   0
# previous_grade                  0
# final_exam_score                0
# final_grade                     0
# dtype: int64

# %%
df = df.drop('parental_education',axis=1)

# %%
df
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lr = LabelEncoder()

# %%
x = df.drop('final_grade',axis=1)

# %%
df['gender'] = lr.fit_transform(df['gender'])

# %%
lr.classes_
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['internet_access'] = lr.fit_transform(df['internet_access'])

# %%
df['extracurricular_activities'] = lr.fit_transform(df['extracurricular_activities'])

# %%
df['part_time_job'] = lr.fit_transform(df['part_time_job'])

# %%
y = df['final_grade']

# %%
x
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 0             1    Male               4.0                98.0          6.5
# 1             2  Female               6.3               100.0          5.7
# 2             3    Male               4.9                85.3          7.9
# 3             4    Male               2.6                77.5          8.0
# 4             5    Male               2.2                89.6          4.6
# ..          ...     ...               ...                 ...          ...
# 995         996    Male               2.8                75.4          8.2
# 996         997    Male               6.7                88.4          7.1
# 997         998  Female               2.6                84.5          8.0
# 998         999  Female               4.6                85.3          8.1
# 999        1000    Male               3.9                77.4          6.1
#
# ...

# %%
y
# Out:
# 0      A
# 1      A
# 2      A
# 3      B
# 4      D
#       ..
# 995    C
# 996    A
# 997    C
# 998    B
# 999    C
# Name: final_grade, Length: 1000, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.2)

# %%
x_test
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 169         170       0               2.9                88.7          7.4
# 101         102       0               1.9                67.4          6.7
# 64           65       1               3.4                88.1          5.7
# 388         389       1               4.4                77.6          6.2
# 364         365       1               2.1                58.0          8.9
# ..          ...     ...               ...                 ...          ...
# 675         676       1               0.5                83.6          6.4
# 482         483       1               4.5                74.1          7.4
# 528         529       0               3.4                67.0          7.6
# 746         747       1               5.9                91.7          4.7
# 794         795       1               3.8                83.1          8.0
#
#      internet_access  extracurricular_activities  part_time_job  \
# ...

# %%
y_test
# Out:
# 169    C
# 101    D
# 64     B
# 388    B
# 364    F
#       ..
# 675    D
# 482    B
# 528    B
# 746    A
# 794    B
# Name: final_grade, Length: 800, dtype: object

# %%
x_train
# Out:
#      student_id  gender  study_time_hours  attendance_percent  sleep_hours  \
# 542         543       1               5.8                96.0          8.7
# 0             1       1               4.0                98.0          6.5
# 839         840       1               3.3                98.2          5.6
# 82           83       1               2.7                73.0          7.6
# 265         266       0               5.2                88.3          8.6
# ..          ...     ...               ...                 ...          ...
# 993         994       0               6.2                87.6          5.9
# 23           24       0               4.3                82.5          5.4
# 35           36       1               6.1                95.7          8.2
# 803         804       1               2.0                90.9          9.0
# 77           78       0               3.8                76.5          5.3
#
#      internet_access  extracurricular_activities  part_time_job  \
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
le = LogisticRegression(max_iter=500000)

# %%
le.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF F,G EVALUATIONS EXCEEDS LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=500000)

# %%
y_predict = le.predict(x_test)

# %%
y_predict
# Out:
# array(['C', 'D', 'B', 'B', 'D', 'C', 'A', 'B', 'C', 'D', 'B', 'B', 'D',
#        'B', 'D', 'C', 'C', 'C', 'A', 'C', 'A', 'C', 'C', 'B', 'A', 'B',
#        'C', 'D', 'B', 'D', 'C', 'B', 'C', 'A', 'B', 'B', 'D', 'B', 'C',
#        'B', 'C', 'B', 'A', 'C', 'C', 'B', 'A', 'B', 'A', 'A', 'A', 'B',
#        'B', 'C', 'B', 'A', 'B', 'C', 'A', 'C', 'C', 'A', 'B', 'D', 'B',
#        'C', 'B', 'D', 'C', 'B', 'B', 'B', 'B', 'A', 'B', 'B', 'C', 'B',
#        'C', 'B', 'B', 'C', 'A', 'D', 'D', 'A', 'A', 'B', 'D', 'B', 'A',
#        'C', 'D', 'A', 'B', 'C', 'C', 'B', 'D', 'C', 'C', 'A', 'C', 'A',
#        'C', 'B', 'A', 'B', 'D', 'A', 'A', 'A', 'B', 'B', 'D', 'C', 'C',
#        'A', 'B', 'A', 'C', 'A', 'B', 'B', 'A', 'A', 'A', 'B', 'A', 'A',
#        'C', 'C', 'B', 'A', 'C', 'B', 'A', 'B', 'B', 'D', 'B', 'B', 'B',
#        'D', 'A', 'D', 'B', 'B', 'B', 'D', 'B', 'B', 'C', 'A', 'B', 'A',
#        'A', 'A', 'C', 'B', 'B', 'A', 'D', 'B', 'C', 'C', 'A', 'C', 'C',
# ...

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.95      0.94      0.94       230
#            B       0.81      0.94      0.87       275
#            C       0.87      0.78      0.82       213
#            D       0.87      0.62      0.72        74
#            F       0.18      0.25      0.21         8
#
#     accuracy                           0.86       800
#    macro avg       0.74      0.71      0.72       800
# weighted avg       0.87      0.86      0.86       800
